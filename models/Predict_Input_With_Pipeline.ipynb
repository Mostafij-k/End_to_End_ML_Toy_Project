# %%
# Import required libraries
import numpy as np
import pickle

# %%
# Import ML model as pipeline
pipe=pickle.load(open('pipe.pkl', 'rb'))

# %%
# Take user input
#Pclass/gender/age/sibSp/parch/fare/embarked
user_input=np.array([2,'male', 31.0, 0, 0, 10.5, 'S'], dtype=object).reshape(1,7)

# %%
# Make prediction
pipe.predict(user_input)
# Out:
# c:\Python3.13.1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Python3.13.1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
